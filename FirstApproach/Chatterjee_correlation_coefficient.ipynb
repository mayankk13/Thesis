# %%
# !pip install xicorrelation
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
from typing import cast

# %%
from xicorrelation import xicorr

# %%
data = pd.read_csv("/content/drive/MyDrive/Datasets/dr16_train.csv")
data.head()
# Out:
#           objid  modelMag_u  modelMag_g  modelMag_r  modelMag_i  modelMag_z  \
# 0  1.237680e+18    21.63269    21.27911    21.22550    20.95690    20.82752
# 1  1.237680e+18    19.74829    19.45819    19.33118    19.01371    18.80369
# 2  1.237680e+18    23.74654    23.19651    22.01303    20.80744    19.91660
# 3  1.237680e+18    20.63075    20.25426    20.04478    19.79378    19.70326
# 4  1.237680e+18    21.38126    21.13488    21.09993    20.92882    20.80634
#
#    fiberMag_u  fiberMag_g  fiberMag_r  fiberMag_i  ...  redshift      zerr  \
# 0    22.05036    21.62439    21.64663    21.32027  ...  1.839604  0.001146
# 1    20.10190    19.79539    19.66580    19.35386  ...  2.069321  0.000354
# 2    24.60136    23.64122    22.48040    21.31004  ...  0.814588  0.000212
# 3    20.99431    20.60174    20.40031    20.19795  ...  1.455912  0.000394
# 4    21.85225    21.45860    21.45340    21.19782  ...  1.651130  0.000760
#
# ...

# %%
X = data.iloc[:50000,1:18]

Y = data.iloc[:50000, 1:18]

# %%
for x in X:
  for y in Y:
    xi, pvalue = xicorr(X[x], Y[y])
    print(x,"  ", y)
    print(print("xi", xi))
    #print("pvalue", pvalue)
# Out:
# modelMag_u    modelMag_u
# xi 0.9999400011999794
# None
# modelMag_u    modelMag_g
# xi 0.34883013258277484
# None
# modelMag_u    modelMag_r
# xi 0.14664313212460467
# None
# modelMag_u    modelMag_i
# xi 0.09896067491086036
# None
# modelMag_u    modelMag_z
# xi 0.09459366732314856
# None
# modelMag_u    fiberMag_u
# xi 0.6581043218831892
# None
# modelMag_u    fiberMag_g
# xi 0.3858726337976083
# None
# modelMag_u    fiberMag_r
# xi 0.20521608254943957
# None
# modelMag_u    fiberMag_i
# xi 0.1265069443389023
# None
# modelMag_u    fiberMag_z
# xi 0.10376748013715975
# None
# modelMag_u    petroR50_r
# xi 0.05276663228168177
# None
# modelMag_u    petroR90_r
# xi 0.040761999549318695
# None
# modelMag_u    petroR50_z
# xi 0.03474289755463611
# None
# modelMag_u    petroR90_z
# xi 0.02836124325888867
# None
# modelMag_u    r
# xi 0.14664313212460467
# None
# modelMag_u    i
# xi 0.09896067491086036
# None
# modelMag_u    z
# xi 0.09459366732314856
# None
# modelMag_g    modelMag_u
# ...
